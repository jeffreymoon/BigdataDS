# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
df = pd.read_csv('./data/nyc.2019-01.csv')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2               2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3               2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4               2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...           ...                  ...                   ...              ...
# 7667787         2  2019-01-31 23:57:36   2019-02-01 00:18:39                1
# 7667788         2  2019-01-31 23:32:03   2019-01-31 23:33:11                1
# 7667789         2  2019-01-31 23:36:36   2019-01-31 23:36:40                1
# 7667790         2  2019-01-31 23:14:53   2019-01-31 23:15:20                1
# 7667791         2  2019-01-31 23:12:49   2019-01-31 23:14:08                1
#
# ...

# %%
df['trip_duration'] = (pd.to_datetime(df['tpep_dropoff_datetime']) - pd.to_datetime(df['tpep_pickup_datetime'])).dt.total_seconds().div(60).astype(float)
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2               2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3               2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4               2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...           ...                  ...                   ...              ...
# 7667787         2  2019-01-31 23:57:36   2019-02-01 00:18:39                1
# 7667788         2  2019-01-31 23:32:03   2019-01-31 23:33:11                1
# 7667789         2  2019-01-31 23:36:36   2019-01-31 23:36:40                1
# 7667790         2  2019-01-31 23:14:53   2019-01-31 23:15:20                1
# 7667791         2  2019-01-31 23:12:49   2019-01-31 23:14:08                1
#
# ...

# %%
(df['trip_duration']).min()
# Out:
# -84280.5

# %%
(df['trip_duration']).max()
# Out:
# 43648.01666666667

# %%
df = df[df['trip_duration'] > 0]

# %%
df = df[df['trip_duration'] < 2000]

# %%
df['trip_duration'].max()
# Out:
# 1687.0333333333333

# %%
df['trip_duration'].value_counts()
# Out:
# 5.150000       10261
# 5.133333       10047
# 5.116667        9236
# 5.066667        9216
# 6.166667        9110
#                ...
# 96.033333          1
# 96.966667          1
# 1331.600000        1
# 1340.900000        1
# 468.583333         1
# Name: trip_duration, Length: 12169, dtype: int64

# %%
df['pick_day'] = pd.to_datetime(df['tpep_pickup_datetime']).dt.day_name()
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2               2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3               2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4               2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...           ...                  ...                   ...              ...
# 7667787         2  2019-01-31 23:57:36   2019-02-01 00:18:39                1
# 7667788         2  2019-01-31 23:32:03   2019-01-31 23:33:11                1
# 7667789         2  2019-01-31 23:36:36   2019-01-31 23:36:40                1
# 7667790         2  2019-01-31 23:14:53   2019-01-31 23:15:20                1
# 7667791         2  2019-01-31 23:12:49   2019-01-31 23:14:08                1
#
# ...

# %%
df['pick_day'].value_counts()
# Out:
# Thursday     1350425
# Wednesday    1258658
# Tuesday      1202878
# Friday       1081875
# Saturday     1007030
# Monday        903702
# Sunday        856926
# Name: pick_day, dtype: int64

# %%
df['passenger_count'].value_counts()
# Out:
# 1    5451155
# 2    1113443
# 5     323760
# 3     314550
# 6     200770
# 4     140649
# 0     117111
# 8         28
# 7         19
# 9          9
# Name: passenger_count, dtype: int64

# %%
df['pickup_hour'] = pd.to_datetime(df['tpep_pickup_datetime']).dt.hour

# %%
df['pickup_hour'].value_counts().nlargest(10)
# Out:
# 18    513625
# 19    474014
# 17    466046
# 15    450029
# 14    430715
# 20    422119
# 16    418232
# 21    408932
# 13    402117
# 12    399026
# Name: pickup_hour, dtype: int64

# %%
df.groupby('VendorID')['fare_amount'].mean().reset_index()
# Out:
#    VendorID  fare_amount
# 0         1    12.016892
# 1         2    12.507774
# 2         4    11.563717

# %%
df['days'] = (pd.to_datetime(df['tpep_dropoff_datetime']).dt.strftime('%m/%d/%y')
# Out:
#   File "<ipython-input-78-d99234839f32>", line 1
#     df['days'] = (pd.to_datetime(df['tpep_dropoff_datetime']).dt.strftime('%m/%d/%y')
#                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
df_loc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-b37889b89f60> in <module>
# ----> 1 df_loc
#
# NameError: name 'df_loc' is not defined
